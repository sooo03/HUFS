# %%
time_list = [100, 500, 1000, 5000, 10000, 50000, 100000, 500000]

# %%
quick_t=[0.000104, 0.000626, 0.001907, 0.008605, 0.018191, 0.128193, 0.294182, 1.883432]
merge_t=[0.000228, 0.001413, 0.003801, 0.018684, 0.039435, 0.297848, 0.630938, 3.912127]
heap_t=[0.000206, 0.001439, 0.004123, 0.021377, 0.067737, 0.390858, 0.878343, 6.781820]

# %%
import matplotlib.pyplot as plt
plt.plot(time_list, quick_t)
plt.plot(time_list, merge_t)
plt.plot(time_list, heap_t)
plt.title("Time")
plt.xlabel('input')
plt.ylabel('Time')
plt.show()

# %%
quick_c= [444, 3513, 7065, 42356, 84474, 560434, 993477, 4893637]
merge_c= [537, 3870, 8730, 55262, 120412, 718241, 1536643, 8836316]
heap_c= [276, 2008, 4549, 28504, 61667, 366595, 783742, 4514823]

# %%
plt.plot(time_list, quick_c)
plt.plot(time_list, merge_c)
plt.plot(time_list, heap_c)
plt.title("Comparison")
plt.xlabel('input')
plt.ylabel('Comparison')
plt.show()

# %%
quick_s=[16, 109, 1625, 2490, 3639, 230314, 514258,3144474]
merge_s= [13, 61, 654, 1246, 1320, 66223, 132285, 639396]
heap_s= [48, 351, 5213, 8063, 11421, 687210, 1474318, 8520669]

# %%
plt.plot(time_list, quick_s)
plt.plot(time_list, merge_s)
plt.plot(time_list, heap_s)
plt.title("Swap")
plt.xlabel('input')
plt.ylabel('Swap')
plt.show()
